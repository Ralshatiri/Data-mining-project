# %% [markdown]
# Student Information:
# --------------------------------
# Student1 Name: Sara Alhowaimel               Student1 ID: 444200462
# Student2 Name: Rahaf Alshatiri             Student2 ID: 444200987
# Student3 Name:  Lamya Alnahdi              Student3 ID: 443202647
# Student4 Name:  Ghaida Alhussain              Student4 ID: 444201213
#
#
#
# Project Motivations:
# --------------------------------
# Diabetes has become increasingly prevalent in recent years, affecting a growing number of people and posing serious
# health risks. This chronic disease can lead to severe complications such as cardiovascular issues, kidney damage,
# and nerve problems, which may even be life-threatening. In our project, we will analyze patient data to explore the
# underlying factors and risks that contribute to the development of diabetes.
#
#
# Project Goal:
# --------------------------------
# The goal of this project is to analyze a diabetes dataset to identify key risk factors and predict the likelihood
# of a patient developing diabetes. By utilizing clustering and classification techniques, the project aims to improve
# predictive accuracy and provide insights that can aid in early detection and more effective prevention strategies.
#
#
# Information About Dataset:
# --------------------------------
# Number of objects: 952
# Number of columns:18
# Dataset link: https://www.kaggle.com/datasets/tigganeha4/diabetes-dataset-2019?resource=download
# Class Lable: Diabetic or not
#
# Attributes:
# --------------------------------
# 1- Name: Age
# Description: The age of the patient(in years).
# Type: Numeric(Ratio)
#
#
# 2- Name: Gender
# Description: The gender of the patient.
# Type: Binary(Symmetric)
#
#
# 3- Name: Family_Diabetes
# Description: Whether the patient has a family history of diabetes.
# Type: Binary(Asymmetric)
#
#
# 4- Name: highBP
# Description: Indicates if the patient has high blood pressure.
# Type: Binary(Asymmetric)
#
#
# 5- Name: PhysicallyActive
# Description: Measures how often the patient is physically active.
# Type: Ordinal
#
#
# 6- Name: BMI
# Description: The patient's Body Mass Index, indicating body fat based on height and weight.
# Type: Numeric(Interval)
#
#
# 7- Name: Smoking
# Description: Whether the patient smokes.
# Type: Binary(Asymmetric)
#
#
# 8- Name: Alcohol
# Description: Indicates whether the patient consumes alcohol.
# Type: Binary(Asymmetric)
#
# 9- Name: Sleep
# Description: The average number of hours of sleep per night.
# Type: Numeric(Interval)
#
# 10- Name: SoundSleep
# Description: The number of hours of restful or deep sleep per night.
# Type: Numeric(Interval)
#
#
# 11- Name: RegularMedicine
# Description: Indicates if the patient regularly takes prescribed medication.
# Type: Binary(Asymmetric)
#
#
# 12- Name: JunkFood
# Description: Frequency of consuming junk or unhealthy food.
# Type: Ordinal
#
#
# 13- Name: Stress
# Description: The level of stress experienced by the patient.
# Type: Ordinal
#
#
# 14- Name: BPLevel
# Description: The patient's blood pressure level.
# Type: Ordinal
#
#
# 15- Name: Pregancies
# Description: Number of times the patient has been pregnant.
# Type: Numeric(Ratio)
#
#
# 16- Name: Pdiabetes
# Description: Indicates whether the patient has been diagnosed with pre-diabetes, a condition where blood sugar levels are higher than normal but not yet high enough for a diabetes diagnosis.
# Type: Binary(Asymmetric)
#
#
# 17- Name: UriationFreq
# Description: Frequency of urination, which can be a symptom of diabetes.
#
#
# 18- Name: Diabetic
# Description: Indicates whether the patient has been diagnosed with diabetes.Indicates whether the patient has been diagnosed with diabetes.
# Type: Binary(Asymmetric)

# %%
# Import pandas library 
import pandas as pd

#Loading dataset
# pd.read_csv() --> used to load a comma separated file (csv) into a dataframe
# -------------------------------------------------
Diabetes_DataFrame = pd.read_csv("diabetes_dataset__2019.csv")
display(Diabetes_DataFrame)

print("-"*40) # Printing separator

# Displying the information of dataset
# info() --> prints the information about data frame such as number of columns, 
# column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values).
# -------------------------------------------------
Diabetes_DataFrame.info()


print("-"*40) # Printing separator


# Display number of rows 
# shape[index] --> will print the number of rows or columns based on index or it can print both if we remove index
# -------------------------------------------------
num_of_rows=Diabetes_DataFrame.shape[0]
print(f"Number of rows is: {num_of_rows}")

# Counting the number of null values in our Dataset
# pd.isnull(dataframe).sum().sum()--> is uesed to count the number of null values in dataframe.
# -------------------------------------------------
count = pd.isnull(Diabetes_DataFrame).sum().sum()
print(f"The Number Of Null Values Is: {count}")

# Display number of columns 
# shape[index] --> will print the number of rows or columns based on index or it can print both if we remove index
# -------------------------------------------------
num_of_columns=Diabetes_DataFrame.shape[1]
print(f"Number of columns is: {num_of_columns}\n")


# Display columns names
# columns --> used to display columns names in dataframe
# -------------------------------------------------
print(f"Columns names are:\n {Diabetes_DataFrame.columns}")

# Display data types
# dtypes --> used to display the data type of attributes
# -------------------------------------------------
print(f"Data types are:\n {Diabetes_DataFrame.dtypes}")

print("-"*40) # Printing separator

# Display the first 5 rows in data set
# head() --> used to display rows at the beginning,number of rows can be specified in the parameter
# -------------------------------------------------
print(f"The first 5 rows are:\n {Diabetes_DataFrame.head(5)}")

# Display the last 5 rows in data set
# tail() --> used to display rows at the end,number of rows can be specified in the parameter
# -------------------------------------------------
print(f"The last 5 rows are:\n {Diabetes_DataFrame.tail(5)}")
# Out:
#               Age  Gender Family_Diabetes highBP      PhysicallyActive   BMI  \
# 0           50-59    Male              no    yes        one hr or more  39.0
# 1           50-59    Male              no    yes  less than half an hr  28.0
# 2           40-49    Male              no     no        one hr or more  24.0
# 3           50-59    Male              no     no        one hr or more  23.0
# 4           40-49    Male              no     no  less than half an hr  27.0
# ..            ...     ...             ...    ...                   ...   ...
# 947  less than 40    Male             yes     no  more than half an hr  25.0
# 948   60 or older    Male             yes    yes  more than half an hr  27.0
# 949   60 or older    Male              no    yes                  none  23.0
# 950   60 or older    Male              no    yes  less than half an hr  27.0
# 951   60 or older  Female             yes    yes        one hr or more  30.0
#
#     Smoking Alcohol  Sleep  SoundSleep RegularMedicine      JunkFood  \
# 0        no      no      8           6              no  occasionally
# 1        no      no      8           6             yes    very often
# 2        no      no      6           6              no  occasionally
# 3        no      no      8           6              no  occasionally
# 4        no      no      8           8              no  occasionally
# ..      ...     ...    ...         ...             ...           ...
# 947      no      no      8           6              no         often
# 948      no      no      6           5             yes  occasionally
# 949      no      no      6           5             yes  occasionally
# 950      no     yes      6           5             yes  occasionally
# 951      no      no      7           4             yes  occasionally
#
#          Stress BPLevel  Pregancies Pdiabetes UriationFreq Diabetic
# 0     sometimes    high         0.0         0     not much       no
# 1     sometimes  normal         0.0         0     not much       no
# 2     sometimes  normal         0.0         0     not much       no
# 3     sometimes  normal         0.0         0     not much       no
# 4     sometimes  normal         0.0         0     not much       no
# ..          ...     ...         ...       ...          ...      ...
# 947   sometimes  normal         0.0         0     not much      yes
# 948   sometimes    high         0.0         0  quite often      yes
# 949   sometimes    high         0.0         0     not much       no
# 950  very often    high         0.0         0     not much       no
# 951   sometimes    high         2.0         0  quite often      yes
#
# [952 rows x 18 columns]
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952 entries, 0 to 951
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               952 non-null    object
#  1   Gender            952 non-null    object
#  2   Family_Diabetes   952 non-null    object
#  3   highBP            952 non-null    object
#  4   PhysicallyActive  952 non-null    object
#  5   BMI               948 non-null    float64
#  6   Smoking           952 non-null    object
#  7   Alcohol           952 non-null    object
#  8   Sleep             952 non-null    int64
#  9   SoundSleep        952 non-null    int64
#  10  RegularMedicine   952 non-null    object
#  11  JunkFood          952 non-null    object
#  12  Stress            952 non-null    object
#  13  BPLevel           952 non-null    object
#  14  Pregancies        910 non-null    float64
#  15  Pdiabetes         951 non-null    object
#  16  UriationFreq      952 non-null    object
#  17  Diabetic          951 non-null    object
# dtypes: float64(2), int64(2), object(14)
# memory usage: 81.9+ KB
# ----------------------------------------
# Number of rows is: 952
# The Number Of Null Values Is: 48
# Number of columns is: 18
#
# Columns names are:
#  Index(['Age', 'Gender', 'Family_Diabetes', 'highBP', 'PhysicallyActive', 'BMI',
#        'Smoking', 'Alcohol', 'Sleep', 'SoundSleep', 'RegularMedicine',
#        'JunkFood', 'Stress', 'BPLevel', 'Pregancies', 'Pdiabetes',
#        'UriationFreq', 'Diabetic'],
#       dtype='object')
# Data types are:
#  Age                  object
# Gender               object
# Family_Diabetes      object
# highBP               object
# PhysicallyActive     object
# BMI                 float64
# Smoking              object
# Alcohol              object
# Sleep                 int64
# SoundSleep            int64
# RegularMedicine      object
# JunkFood             object
# Stress               object
# BPLevel              object
# Pregancies          float64
# Pdiabetes            object
# UriationFreq         object
# Diabetic             object
# dtype: object
# ----------------------------------------
# The first 5 rows are:
#       Age Gender Family_Diabetes highBP      PhysicallyActive   BMI Smoking  \
# 0  50-59   Male              no    yes        one hr or more  39.0      no
# 1  50-59   Male              no    yes  less than half an hr  28.0      no
# 2  40-49   Male              no     no        one hr or more  24.0      no
# 3  50-59   Male              no     no        one hr or more  23.0      no
# 4  40-49   Male              no     no  less than half an hr  27.0      no
#
#   Alcohol  Sleep  SoundSleep RegularMedicine      JunkFood     Stress BPLevel  \
# 0      no      8           6              no  occasionally  sometimes    high
# 1      no      8           6             yes    very often  sometimes  normal
# 2      no      6           6              no  occasionally  sometimes  normal
# 3      no      8           6              no  occasionally  sometimes  normal
# 4      no      8           8              no  occasionally  sometimes  normal
#
#    Pregancies Pdiabetes UriationFreq Diabetic
# 0         0.0         0     not much       no
# 1         0.0         0     not much       no
# 2         0.0         0     not much       no
# 3         0.0         0     not much       no
# 4         0.0         0     not much       no
# The last 5 rows are:
#                Age  Gender Family_Diabetes highBP      PhysicallyActive   BMI  \
# 947  less than 40    Male             yes     no  more than half an hr  25.0
# 948   60 or older    Male             yes    yes  more than half an hr  27.0
# 949   60 or older    Male              no    yes                  none  23.0
# 950   60 or older    Male              no    yes  less than half an hr  27.0
# 951   60 or older  Female             yes    yes        one hr or more  30.0
#
#     Smoking Alcohol  Sleep  SoundSleep RegularMedicine      JunkFood  \
# 947      no      no      8           6              no         often
# 948      no      no      6           5             yes  occasionally
# 949      no      no      6           5             yes  occasionally
# 950      no     yes      6           5             yes  occasionally
# 951      no      no      7           4             yes  occasionally
#
#          Stress BPLevel  Pregancies Pdiabetes UriationFreq Diabetic
# 947   sometimes  normal         0.0         0     not much      yes
# 948   sometimes    high         0.0         0  quite often      yes
# 949   sometimes    high         0.0         0     not much       no
# 950  very often    high         0.0         0     not much       no
# 951   sometimes    high         2.0         0  quite often      yes
# 4
# 11
